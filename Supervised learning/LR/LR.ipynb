# %% [markdown]
# Linear Regression is a machine learning algorithm based on supervised learning. It performs a regression task. Regression models a target prediction value based on independent variables. It is mostly used for finding out the relationship between variables and forecasting. Different regression models differ based on – the kind of relationship between dependent and independent variables they are considering, and the number of independent variables getting used.

# %%
# Import necessary modules
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
from sklearn.metrics import classification_report
from sklearn.linear_model import LinearRegression
import sklearn.metrics as sm

# %%
#loading our data and we are predicting the value of rings using Longestshell parameter
#one input feature and is called as simple linear regression model
Data = pd.read_csv("C:\\Users\\GowriPrasanthRamsamy\\prashanth\\LR\\dataset.csv")
Data.head()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
#determing the rows and columns of our data
Data.shape
# Out:
# (4177, 9)

# %%
#estimating mean,sd and other stuffs of statistical data
Data.describe()
# Out:
#        LongestShell     Diameter       Height  WholeWeight  ShuckedWeight  \
# count   4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean       0.523992     0.407881     0.139516     0.828742       0.359367
# std        0.120093     0.099240     0.041827     0.490389       0.221963
# min        0.075000     0.055000     0.000000     0.002000       0.001000
# 25%        0.450000     0.350000     0.115000     0.441500       0.186000
# 50%        0.545000     0.425000     0.140000     0.799500       0.336000
# 75%        0.615000     0.480000     0.165000     1.153000       0.502000
# max        0.815000     0.650000     1.130000     2.825500       1.488000
#
#        VisceraWeight  ShellWeight        Rings
# count    4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684
# std         0.109614     0.139203     3.224169
# min         0.000500     0.001500     1.000000
# 25%         0.093500     0.130000     8.000000
# ...

# %%
#info about the type
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           4177 non-null   object
#  1   LongestShell   4177 non-null   float64
#  2   Diameter       4177 non-null   float64
#  3   Height         4177 non-null   float64
#  4   WholeWeight    4177 non-null   float64
#  5   ShuckedWeight  4177 non-null   float64
#  6   VisceraWeight  4177 non-null   float64
#  7   ShellWeight    4177 non-null   float64
#  8   Rings          4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
#visualising the given data and determing our input feature.
sns.pairplot(Data)
plt.show()

# %%
#considering the input feature as longestshell plotting it with rings to see it
plt.figure(figsize=(24,20))
sns.lmplot(x='LongestShell', y='Rings', data = Data,ci=None)
plt.show()
x= np.array(Data['LongestShell']).reshape(-1,1)
y= np.array(Data['Rings']).reshape(-1,1)

# %%
rows, col = Data.shape

# %% [markdown]
# #fitting our model using linear regression package and finding our score

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5)
regr = LinearRegression()

regr.fit(X_train,y_train)
print(regr.score(X_test,y_test))
# Out:
# 0.2862752430422626

# %% [markdown]
# #plotting to visualise our trainned model

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test,y_test,color='yellow')
plt.plot(X_test,y_pred,color='green')
plt.show()

# %% [markdown]
# #Made multiple LR Model for given input and testing accuracy.

# %%
plt.figure(figsize=(24,20))
sns.lmplot(x='Diameter', y='Rings', data = Data,ci=None)
plt.show()
x= np.array(Data['Diameter']).reshape(-1,1)
y= np.array(Data['Rings']).reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5)
regr = LinearRegression()

regr.fit(X_train,y_train)
print(regr.score(X_test,y_test))
# Out:
# 0.33359687268607274

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test,y_test,color='yellow')
plt.plot(X_test,y_pred,color='green')
plt.show()

# %%
plt.figure(figsize=(24,20))
sns.lmplot(x='Height', y='Rings', data = Data,ci=None)
plt.show()
x= np.array(Data['Height']).reshape(-1,1)
y= np.array(Data['Rings']).reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5)
regr = LinearRegression()

regr.fit(X_train,y_train)
print(regr.score(X_test,y_test))
# Out:
# 0.2200049969678496

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test,y_test,color='yellow')
plt.plot(X_test,y_pred,color='green')
plt.show()

# %%
plt.figure(figsize=(24,20))
sns.lmplot(x='ShellWeight', y='Rings', data = Data,ci=None)
plt.show()
x= np.array(Data['ShellWeight']).reshape(-1,1)
y= np.array(Data['Rings']).reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5)
regr = LinearRegression()

regr.fit(X_train,y_train)
print(regr.score(X_test,y_test))
# Out:
# 0.39214492303754644

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test,y_test,color='yellow')
plt.plot(X_test,y_pred,color='green')
plt.show()

# %%
plt.figure(figsize=(24,20))
sns.lmplot(x='ShuckedWeight', y='Rings', data = Data,ci=None)
plt.show()
x= np.array(Data['ShuckedWeight']).reshape(-1,1)
y= np.array(Data['Rings']).reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.5)
regr = LinearRegression()

regr.fit(X_train,y_train)
print(regr.score(X_test,y_test))
# Out:
# 0.17695591174488334

# %%
y_pred = regr.predict(X_test)
plt.scatter(X_test,y_test,color='yellow')
plt.plot(X_test,y_pred,color='green')
plt.show()
